# %%
def fun(n):
    r=n+6
    return r

fun(8)
# Out:
# 14

# %%
for k in range(7):
    print(k+45)
# Out:
# 45
# 46
# 47
# 48
# 49
# 50
# 51

# %% [markdown]
# # lista nueva
#
# ojo esto lo hice desde johnfernando b

# %%
L=[3,4,5,7]
for k in L:
    print(f"{k+10} ojo esto esta dañado" )
# Out:
# 13 ojo esto esta dañado
# 14 ojo esto esta dañado
# 15 ojo esto esta dañado
# 17 ojo esto esta dañado
